# %%
import pandas as pd

# %%
import numpy as np

# %%
file='./public_project/데이터산업_시장규모 1.csv'

# %%
DF=pd.read_csv(file,encoding='utf-8-sig')
DF
# Out:
#                 데이터산업별(1)    2015    2016    2017    2018    2019    2020  \
# 0                      전체  133555  137547  143530  155684  168582  200024
# 1  데이터 처리 및 관리 솔루션 개발·공급업   14124   15720   16457   18617   20805   25133
# 2       데이터 구축 및 컨설팅 서비스업   55280   55850   58894   61290   65412   76999
# 3        데이터 판매 및 제공 서비스업   64151   65977   68179   75778   82364   97891
#
#      2021  2022 e)
# 0  228986   250527
# 1   29843    32723
# 2   85274    92570
# 3  113869   125235

# %%
DF.columns
# Out:
# Index(['데이터산업별(1)', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        '2022 e)'],
#       dtype='object')

# %%
DF.rename(columns={'2022 e)':'2022'},inplace=True)
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   데이터산업별(1)  4 non-null      object
#  1   2015       4 non-null      int64
#  2   2016       4 non-null      int64
#  3   2017       4 non-null      int64
#  4   2018       4 non-null      int64
#  5   2019       4 non-null      int64
#  6   2020       4 non-null      int64
#  7   2021       4 non-null      int64
#  8   2022       4 non-null      int64
# dtypes: int64(8), object(1)
# memory usage: 416.0+ bytes

# %%
row_sum=DF.iloc[:,1:].sum(axis=1)

# %%
row_sum
# Out:
# 0    1418435
# 1     173422
# 2     551569
# 3     693444
# dtype: int64

# %%
DF.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
DF.rename(index={'전체':'연도별 합계'},inplace=True)
DF
# Out:
#                 데이터산업별(1)    2015    2016    2017    2018    2019    2020  \
# 0                      전체  133555  137547  143530  155684  168582  200024
# 1  데이터 처리 및 관리 솔루션 개발·공급업   14124   15720   16457   18617   20805   25133
# 2       데이터 구축 및 컨설팅 서비스업   55280   55850   58894   61290   65412   76999
# 3        데이터 판매 및 제공 서비스업   64151   65977   68179   75778   82364   97891
#
#      2021    2022
# 0  228986  250527
# 1   29843   32723
# 2   85274   92570
# 3  113869  125235

# %%
DF_no_index_name = DF.rename_axis(None)

# %%
DF_no_index_name
# Out:
#                 데이터산업별(1)    2015    2016    2017    2018    2019    2020  \
# 0                      전체  133555  137547  143530  155684  168582  200024
# 1  데이터 처리 및 관리 솔루션 개발·공급업   14124   15720   16457   18617   20805   25133
# 2       데이터 구축 및 컨설팅 서비스업   55280   55850   58894   61290   65412   76999
# 3        데이터 판매 및 제공 서비스업   64151   65977   68179   75778   82364   97891
#
#      2021    2022
# 0  228986  250527
# 1   29843   32723
# 2   85274   92570
# 3  113869  125235

# %%
# 데이터산업시장규모 시각화
import matplotlib.pyplot as plt
import platform
import koreanize_matplotlib

# %%
data = {
    '연도별 합계': [133555, 137547, 143530, 155684, 168582, 200024, 228986, 250527],
    '데이터 처리 및 관리 솔루션 개발·공급업': [14124, 15720, 16457, 18617, 20805, 25133, 29843, 32723],
    '데이터 구축 및 컨설팅 서비스업': [55280, 55850, 58894, 61290, 65412, 76999, 85274, 92570],
    '데이터 판매 및 제공 서비스업': [64151, 65977, 68179, 75778, 82364, 97891, 113869, 125235]
}

# 데이터프레임 생성
df = pd.DataFrame(data)

# 인덱스 설정
df.index = ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']

# 막대 차트 그리기
df.plot(kind='bar', figsize=(10, 4))
plt.title('데이터 시장 규모')
plt.xlabel('연도')
plt.ylabel('데이터 양')
plt.xticks(rotation=45)
plt.legend(title='업종')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3944755787.py:21: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3944755787.py:21: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3944755787.py:21: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   plt.tight_layout()
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3944755787.py:21: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   plt.tight_layout()
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3944755787.py:21: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   plt.tight_layout()
# ...

# %%
# 전체 시장규모 파악 후 각 세션 별로 분류 
# 데이터 처리 및 관리 솔루션 개발 공급업

# %%
# 데이터 처리 및 관리 솔루션 개발 공급업 
file2='./public_project/데이터처리및관리솔루션개발·공급업영역별시장규모2.csv'

# %%
DF2=pd.read_csv(file2,encoding='utf-8')
DF2
# Out:
#                      중분류별(1) 영역별(1)   2015   2016   2017   2018   2019   2020  \
# 0                         전체      계  14124  15720  16457  18617  20805  25133
# 1                         전체   라이선스   3941   4372   6592   2682   2233   2821
# 2                         전체     개발   6576   7118   5489   8492  11035  13394
# 3                         전체   유지보수   3607   4230   4375   7441   7537   8918
# 4       데이터 수집·연계 솔루션 개발·공급업      계   1115   1345   1393   1622   1871   2122
# 5       데이터 수집·연계 솔루션 개발·공급업   라이선스    225    277    306    197    177    203
# 6       데이터 수집·연계 솔루션 개발·공급업     개발    523    681    697    885   1125   1192
# 7       데이터 수집·연계 솔루션 개발·공급업   유지보수    367    387    390    540    569    727
# 8   데이터베이스 관리 시스템 솔루션 개발·공급업      계   5727   6148   6121   6775   7510   8979
# 9   데이터베이스 관리 시스템 솔루션 개발·공급업   라이선스   2712   2880   3489   1639    837    968
# 10  데이터베이스 관리 시스템 솔루션 개발·공급업     개발   2101   2184   1102   2326   3978   4663
# ...

# %%
DF2.rename(columns={'2022 e)':'2022'},inplace=True)
DF2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   중분류별(1)  28 non-null     object
#  1   영역별(1)   28 non-null     object
#  2   2015     28 non-null     object
#  3   2016     28 non-null     object
#  4   2017     28 non-null     int64
#  5   2018     28 non-null     int64
#  6   2019     28 non-null     int64
#  7   2020     28 non-null     int64
#  8   2021     28 non-null     int64
#  9   2022     28 non-null     int64
# dtypes: int64(6), object(4)
# memory usage: 2.3+ KB

# %%
DF2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   중분류별(1)  28 non-null     object
#  1   영역별(1)   28 non-null     object
#  2   2015     28 non-null     object
#  3   2016     28 non-null     object
#  4   2017     28 non-null     int64
#  5   2018     28 non-null     int64
#  6   2019     28 non-null     int64
#  7   2020     28 non-null     int64
#  8   2021     28 non-null     int64
#  9   2022     28 non-null     int64
# dtypes: int64(6), object(4)
# memory usage: 2.3+ KB

# %%
DF2[['2015','2016']] =DF2[['2015','2016']].apply(lambda x : pd.to_numeric(x,errors='coerce'))

# %%
DF2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   중분류별(1)  28 non-null     object
#  1   영역별(1)   28 non-null     object
#  2   2015     24 non-null     float64
#  3   2016     24 non-null     float64
#  4   2017     28 non-null     int64
#  5   2018     28 non-null     int64
#  6   2019     28 non-null     int64
#  7   2020     28 non-null     int64
#  8   2021     28 non-null     int64
#  9   2022     28 non-null     int64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 2.3+ KB

# %%
DF2
# Out:
#                      중분류별(1) 영역별(1)     2015     2016   2017   2018   2019  \
# 0                         전체      계  14124.0  15720.0  16457  18617  20805
# 1                         전체   라이선스   3941.0   4372.0   6592   2682   2233
# 2                         전체     개발   6576.0   7118.0   5489   8492  11035
# 3                         전체   유지보수   3607.0   4230.0   4375   7441   7537
# 4       데이터 수집·연계 솔루션 개발·공급업      계   1115.0   1345.0   1393   1622   1871
# 5       데이터 수집·연계 솔루션 개발·공급업   라이선스    225.0    277.0    306    197    177
# 6       데이터 수집·연계 솔루션 개발·공급업     개발    523.0    681.0    697    885   1125
# 7       데이터 수집·연계 솔루션 개발·공급업   유지보수    367.0    387.0    390    540    569
# 8   데이터베이스 관리 시스템 솔루션 개발·공급업      계   5727.0   6148.0   6121   6775   7510
# 9   데이터베이스 관리 시스템 솔루션 개발·공급업   라이선스   2712.0   2880.0   3489   1639    837
# 10  데이터베이스 관리 시스템 솔루션 개발·공급업     개발   2101.0   2184.0   1102   2326   3978
# ...

# %%
for row in DF2.index[20:24]:
    DF2.loc[row] = DF2.loc[row].fillna(DF2.loc[row][2:].mean())

DF2
# Out:
#                      중분류별(1) 영역별(1)          2015          2016   2017   2018  \
# 0                         전체      계  14124.000000  15720.000000  16457  18617
# 1                         전체   라이선스   3941.000000   4372.000000   6592   2682
# 2                         전체     개발   6576.000000   7118.000000   5489   8492
# 3                         전체   유지보수   3607.000000   4230.000000   4375   7441
# 4       데이터 수집·연계 솔루션 개발·공급업      계   1115.000000   1345.000000   1393   1622
# 5       데이터 수집·연계 솔루션 개발·공급업   라이선스    225.000000    277.000000    306    197
# 6       데이터 수집·연계 솔루션 개발·공급업     개발    523.000000    681.000000    697    885
# 7       데이터 수집·연계 솔루션 개발·공급업   유지보수    367.000000    387.000000    390    540
# 8   데이터베이스 관리 시스템 솔루션 개발·공급업      계   5727.000000   6148.000000   6121   6775
# 9   데이터베이스 관리 시스템 솔루션 개발·공급업   라이선스   2712.000000   2880.000000   3489   1639
# 10  데이터베이스 관리 시스템 솔루션 개발·공급업     개발   2101.000000   2184.000000   1102   2326
# ...

# %%
import matplotlib.pyplot as plt

# %%
# DF2=DF2.iloc[4::4].reset_index(drop=True)
# plt.figure(figsize=(14,10))
# for i in range(6) :
#     plt.plot(range(8), DF2.iloc[i,2:],label=DF2.iloc[i,0],marker='o',markersize=5,linestyle='--')
# plt.legend()
# plt.title("공급엽영역별 시장규모")
# plt.xticks(range(8), [i for i in range(2015,2023)])
# plt.yscale('log',base=2)
# plt.show()

# %%
# import matplotlib.cm as cm
# import matplotlib as mpl
# cm.hsv

# %%
# mpl.rc('lines', linewidth = 2.)
# mpl.rc('axes', facecolor = 'k', edgecolor = 'w')
# mpl.rc('xtick', color = 'w')
# mpl.rc('ytick', color = 'w')
# mpl.rc('text', color = 'w')
# mpl.rc('figure', facecolor = 'k', edgecolor ='w')
# #mpl.rc('axes', color_cycle = ('w', '.5', '.75'))
# mpl.rc('savefig', facecolor = 'k', edgecolor = 'w')

# gap=0.1
# plt.figure(figsize=(14,10))
# for i in range(8) :
#     plt.bar([ x+i*gap for x in range(6)], DF2.iloc[:,2+i].values, width=0.1, color=cm.hsv(i/8))
# plt.xticks(range(6),DF2.iloc[:,0].values, rotation=60, size=20)
# plt.legend([i for i in range(2015, 2023)])
# plt.title("데이터처리 및 관리 솔루션 개발, 공급영역별 시장규모", size=30)
# plt.grid(True)
# plt.show()
# #mpl.rcdefaults()

# %%
file3='./public_project/3 데이터_구축_및_컨설팅_서비스업_영역별_시장규모.csv'

# %%
DF3=pd.read_csv(file3,encoding='utf-8')
DF3
# Out:
#         구축/컨설팅별(1) 구축/컨설팅별(2)   2015   2016   2017   2018   2019   2020  \
# 0               전체         소계  55280  55850  58894  61290  65412  76999
# 1   데이터 구축·가공 서비스업         소계  54142  54571  57207  58993  62223  72805
# 2   데이터 구축·가공 서비스업       제품판매      -      -  11859  20506  11703  14571
# 3   데이터 구축·가공 서비스업    용역 및 운영      -      -  45348  38487  50519  58234
# 4  데이터 관련 컨설팅 서비스업         소계   1138   1279   1687   2297   3189   4194
#
#     2021  2022 e)
# 0  85274    92570
# 1  80403    87366
# 2  17549    21339
# 3  62855    66027
# 4   4871     5204

# %%
DF3.rename(columns={'2022 e)':'2022'},inplace=True)
DF3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   구축/컨설팅별(1)  5 non-null      object
#  1   구축/컨설팅별(2)  5 non-null      object
#  2   2015        5 non-null      object
#  3   2016        5 non-null      object
#  4   2017        5 non-null      int64
#  5   2018        5 non-null      int64
#  6   2019        5 non-null      int64
#  7   2020        5 non-null      int64
#  8   2021        5 non-null      int64
#  9   2022        5 non-null      int64
# dtypes: int64(6), object(4)
# memory usage: 528.0+ bytes

# %%
DF3[['2015','2016']] =DF3[['2015','2016']].apply(lambda x : pd.to_numeric(x,errors='coerce'))

# %%
DF3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   구축/컨설팅별(1)  5 non-null      object
#  1   구축/컨설팅별(2)  5 non-null      object
#  2   2015        3 non-null      float64
#  3   2016        3 non-null      float64
#  4   2017        5 non-null      int64
#  5   2018        5 non-null      int64
#  6   2019        5 non-null      int64
#  7   2020        5 non-null      int64
#  8   2021        5 non-null      int64
#  9   2022        5 non-null      int64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 528.0+ bytes

# %%
for row in DF3.index[2:4]:
    DF3.loc[row] = DF3.loc[row].fillna(DF3.loc[row][2:].mean())

DF3
# Out:
#         구축/컨설팅별(1) 구축/컨설팅별(2)          2015          2016   2017   2018  \
# 0               전체         소계  55280.000000  55850.000000  58894  61290
# 1   데이터 구축·가공 서비스업         소계  54142.000000  54571.000000  57207  58993
# 2   데이터 구축·가공 서비스업       제품판매  16254.500000  16254.500000  11859  20506
# 3   데이터 구축·가공 서비스업    용역 및 운영  53578.333333  53578.333333  45348  38487
# 4  데이터 관련 컨설팅 서비스업         소계   1138.000000   1279.000000   1687   2297
#
#     2019   2020   2021   2022
# 0  65412  76999  85274  92570
# 1  62223  72805  80403  87366
# 2  11703  14571  17549  21339
# 3  50519  58234  62855  66027
# 4   3189   4194   4871   5204

# %%
indexes_to_drop = [2,3]
DF_con=DF3.drop(indexes_to_drop)

# %%
DF_con
# Out:
#         구축/컨설팅별(1) 구축/컨설팅별(2)     2015     2016   2017   2018   2019   2020  \
# 0               전체         소계  55280.0  55850.0  58894  61290  65412  76999
# 1   데이터 구축·가공 서비스업         소계  54142.0  54571.0  57207  58993  62223  72805
# 4  데이터 관련 컨설팅 서비스업         소계   1138.0   1279.0   1687   2297   3189   4194
#
#     2021   2022
# 0  85274  92570
# 1  80403  87366
# 4   4871   5204

# %%
# 변경할 인덱스 이름과 새로운 이름을 딕셔너리로 정의
new_index_names = {0: '전체소계', 1: '데이터 구축 가공 서비스업 합계',4:'데이터 관련 컨설팅 서비스업 합계'}

# 여러 개의 특정 인덱스 이름 변경
DF_con1 = DF_con.rename(index=new_index_names)

print(DF_con1)
# Out:
#                          구축/컨설팅별(1) 구축/컨설팅별(2)     2015     2016   2017  \
# 전체소계                             전체         소계  55280.0  55850.0  58894
# 데이터 구축 가공 서비스업 합계    데이터 구축·가공 서비스업         소계  54142.0  54571.0  57207
# 데이터 관련 컨설팅 서비스업 합계  데이터 관련 컨설팅 서비스업         소계   1138.0   1279.0   1687
#
#                      2018   2019   2020   2021   2022
# 전체소계                61290  65412  76999  85274  92570
# 데이터 구축 가공 서비스업 합계   58993  62223  72805  80403  87366
# 데이터 관련 컨설팅 서비스업 합계   2297   3189   4194   4871   5204

# %%
DF_con1
# Out:
#                          구축/컨설팅별(1) 구축/컨설팅별(2)     2015     2016   2017  \
# 전체소계                             전체         소계  55280.0  55850.0  58894
# 데이터 구축 가공 서비스업 합계    데이터 구축·가공 서비스업         소계  54142.0  54571.0  57207
# 데이터 관련 컨설팅 서비스업 합계  데이터 관련 컨설팅 서비스업         소계   1138.0   1279.0   1687
#
#                      2018   2019   2020   2021   2022
# 전체소계                61290  65412  76999  85274  92570
# 데이터 구축 가공 서비스업 합계   58993  62223  72805  80403  87366
# 데이터 관련 컨설팅 서비스업 합계   2297   3189   4194   4871   5204

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 막대 차트 그리기
DF_con1.plot(kind='bar', figsize=(12, 4))
plt.title('데이터 구축 및 컨설팅 서비스업 영역별 시장규모')
plt.xlabel('구축/컨설팅별')
plt.ylabel('데이터 양')
plt.xticks(rotation=0)
plt.legend(title='업종')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3536155174.py:11: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.tight_layout()
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3536155174.py:11: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   plt.tight_layout()
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3536155174.py:11: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from current font.
#   plt.tight_layout()
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3536155174.py:11: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   plt.tight_layout()
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3536155174.py:11: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   plt.tight_layout()
# ...

# %%
file4='./public_project/4 데이터_판매_및_제공_서비스업의_수익기반별_시장규모.csv'

# %%
DF4=pd.read_csv(file4,encoding='utf-8-sig')

# %%
DF4
# Out:
#            중분류별(1) 매출별(1)   2015   2016   2017   2018   2019   2020    2021  \
# 0               전체      계  64151  65977  68179  75778  82364  97891  113869
# 1          데이터 거래       계   2379   2594   2918   4175      -      -       -
# 2          데이터 거래    직접매출   2350   2354   2713   3796      -      -       -
# 3          데이터 거래    광고매출     29    240    205    379      -      -       -
# 4   데이터 판매·중개 서비스업      계      -      -      -      -  11332  16054   20861
# 5   데이터 판매·중개 서비스업   직접매출      -      -      -      -   9844  13206   16678
# 6   데이터 판매·중개 서비스업   광고매출      -      -      -      -   1488   2847    4184
# 7        정보제공 서비스업      계  58171  59854  61570  67580  71033  81838   93008
# 8        정보제공 서비스업   직접매출  10726  11523  12747  22673  30764  38039   49400
# 9        정보제공 서비스업   광고매출  47445  48331  48823  44907  40269  43799   43608
# 10       데이터 분석 제공      계   3601   3529   3691   4023      -      -       -
# ...

# %%
DF4.rename(columns={'2022 e)':'2022'},inplace=True)
DF4
# Out:
#            중분류별(1) 매출별(1)   2015   2016   2017   2018   2019   2020    2021  \
# 0               전체      계  64151  65977  68179  75778  82364  97891  113869
# 1          데이터 거래       계   2379   2594   2918   4175      -      -       -
# 2          데이터 거래    직접매출   2350   2354   2713   3796      -      -       -
# 3          데이터 거래    광고매출     29    240    205    379      -      -       -
# 4   데이터 판매·중개 서비스업      계      -      -      -      -  11332  16054   20861
# 5   데이터 판매·중개 서비스업   직접매출      -      -      -      -   9844  13206   16678
# 6   데이터 판매·중개 서비스업   광고매출      -      -      -      -   1488   2847    4184
# 7        정보제공 서비스업      계  58171  59854  61570  67580  71033  81838   93008
# 8        정보제공 서비스업   직접매출  10726  11523  12747  22673  30764  38039   49400
# 9        정보제공 서비스업   광고매출  47445  48331  48823  44907  40269  43799   43608
# 10       데이터 분석 제공      계   3601   3529   3691   4023      -      -       -
# ...

# %%
DF4[['2015','2016','2017','2018','2019','2020','2021','2022']] =DF4[['2015','2016','2017','2018','2019','2020','2021','2022']].apply(lambda x : pd.to_numeric(x,errors='coerce'))

# %%
DF4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   중분류별(1)  13 non-null     object
#  1   매출별(1)   13 non-null     object
#  2   2015     10 non-null     float64
#  3   2016     10 non-null     float64
#  4   2017     10 non-null     float64
#  5   2018     10 non-null     float64
#  6   2019     7 non-null      float64
#  7   2020     7 non-null      float64
#  8   2021     7 non-null      float64
#  9   2022     7 non-null      float64
# dtypes: float64(8), object(2)
# memory usage: 1.1+ KB

# %%
DF5 = {
    
    '2015': [64151, 2379, 2350, 29, None, None, None, 58171, 10726, 47445, 3601, 3052, 549],
    '2016': [65977, 2594, 2354, 240, None, None, None, 59854, 11523, 48331, 3529, 3051, 478],
    '2017': [68179, 2918, 2713, 205, None, None, None, 61570, 12747, 48823, 3691, 2878, 813],
    '2018': [75778, 4175, 3796, 379, None, None, None, 67580, 22673, 44907, 4023, 3633, 390],
    '2019': [82364, None, None, None, 11332, 9844, 1488, 71033, 30764, 40269, None, None, None],
    '2020': [97891, None, None, None, 16054, 13206, 2847, 81838, 38039, 43799, None, None, None],
    '2021': [113869, None, None, None, 20861, 16678, 4184, 93008, 49400, 43608, None, None, None],
    '2022': [125235, None, None, None, 22194, 17782, 4412, 103040, 53244, 49797, None, None, None]
}

# 데이터프레임 생성
DF5 = pd.DataFrame(DF5)

# 결측값을 열의 평균으로 대체
DF5.fillna(DF5.mean(), inplace=True)

print(DF5)
# Out:
#        2015     2016     2017     2018          2019          2020  \
# 0   64151.0  65977.0  68179.0  75778.0  82364.000000  97891.000000
# 1    2379.0   2594.0   2918.0   4175.0  35299.142857  41953.428571
# 2    2350.0   2354.0   2713.0   3796.0  35299.142857  41953.428571
# 3      29.0    240.0    205.0    379.0  35299.142857  41953.428571
# 4   19245.3  19793.1  20453.7  22733.4  11332.000000  16054.000000
# 5   19245.3  19793.1  20453.7  22733.4   9844.000000  13206.000000
# 6   19245.3  19793.1  20453.7  22733.4   1488.000000   2847.000000
# 7   58171.0  59854.0  61570.0  67580.0  71033.000000  81838.000000
# 8   10726.0  11523.0  12747.0  22673.0  30764.000000  38039.000000
# 9   47445.0  48331.0  48823.0  44907.0  40269.000000  43799.000000
# 10   3601.0   3529.0   3691.0   4023.0  35299.142857  41953.428571
# 11   3052.0   3051.0   2878.0   3633.0  35299.142857  41953.428571
# 12    549.0    478.0    813.0    390.0  35299.142857  41953.428571
#
# ...

# %%
DF5
# Out:
#        2015     2016     2017     2018          2019          2020  \
# 0   64151.0  65977.0  68179.0  75778.0  82364.000000  97891.000000
# 1    2379.0   2594.0   2918.0   4175.0  35299.142857  41953.428571
# 2    2350.0   2354.0   2713.0   3796.0  35299.142857  41953.428571
# 3      29.0    240.0    205.0    379.0  35299.142857  41953.428571
# 4   19245.3  19793.1  20453.7  22733.4  11332.000000  16054.000000
# 5   19245.3  19793.1  20453.7  22733.4   9844.000000  13206.000000
# 6   19245.3  19793.1  20453.7  22733.4   1488.000000   2847.000000
# 7   58171.0  59854.0  61570.0  67580.0  71033.000000  81838.000000
# 8   10726.0  11523.0  12747.0  22673.0  30764.000000  38039.000000
# 9   47445.0  48331.0  48823.0  44907.0  40269.000000  43799.000000
# 10   3601.0   3529.0   3691.0   4023.0  35299.142857  41953.428571
# 11   3052.0   3051.0   2878.0   3633.0  35299.142857  41953.428571
# 12    549.0    478.0    813.0    390.0  35299.142857  41953.428571
#
# ...

# %%
indexes_to_drop = [0,2,3,5,6,8,9,11,12]
DF6=DF5.drop(indexes_to_drop)

# %%
# 변경할 인덱스 이름과 새로운 이름을 딕셔너리로 정의
new_index_names = {1: '데이터거래합계', 4: '데이터판매중개서비스업합계',7:'정보제공서비스업합계',10:'데이터분석제공합계'}

# 여러 개의 특정 인덱스 이름 변경
DF6 = DF6.rename(index=new_index_names)

print(DF6)
# Out:
#                   2015     2016     2017     2018          2019          2020  \
# 데이터거래합계         2379.0   2594.0   2918.0   4175.0  35299.142857  41953.428571
# 데이터판매중개서비스업합계  19245.3  19793.1  20453.7  22733.4  11332.000000  16054.000000
# 정보제공서비스업합계     58171.0  59854.0  61570.0  67580.0  71033.000000  81838.000000
# 데이터분석제공합계       3601.0   3529.0   3691.0   4023.0  35299.142857  41953.428571
#
#                        2021      2022
# 데이터거래합계        48801.142857   53672.0
# 데이터판매중개서비스업합계  20861.000000   22194.0
# 정보제공서비스업합계     93008.000000  103040.0
# 데이터분석제공합계      48801.142857   53672.0

# %%
DF6
# Out:
#                   2015     2016     2017     2018          2019          2020  \
# 데이터거래합계         2379.0   2594.0   2918.0   4175.0  35299.142857  41953.428571
# 데이터판매중개서비스업합계  19245.3  19793.1  20453.7  22733.4  11332.000000  16054.000000
# 정보제공서비스업합계     58171.0  59854.0  61570.0  67580.0  71033.000000  81838.000000
# 데이터분석제공합계       3601.0   3529.0   3691.0   4023.0  35299.142857  41953.428571
#
#                        2021      2022
# 데이터거래합계        48801.142857   53672.0
# 데이터판매중개서비스업합계  20861.000000   22194.0
# 정보제공서비스업합계     93008.000000  103040.0
# 데이터분석제공합계      48801.142857   53672.0

# %%
# 막대 차트 그리기
DF6.plot(kind='bar', figsize=(12, 4))
plt.title('데이터판매 및 제공 서비스업의 수익기반별 시장규모')
plt.xlabel('분류별')
plt.ylabel('데이터 양')
plt.xticks(rotation=0)
plt.legend(title='업종')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3063370130.py:8: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   plt.tight_layout()
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3063370130.py:8: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   plt.tight_layout()
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3063370130.py:8: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   plt.tight_layout()
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3063370130.py:8: UserWarning: Glyph 44144 (\N{HANGUL SYLLABLE GEO}) missing from current font.
#   plt.tight_layout()
# C:\Users\desktop\AppData\Local\Temp\ipykernel_12188\3063370130.py:8: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   plt.tight_layout()
# ...
